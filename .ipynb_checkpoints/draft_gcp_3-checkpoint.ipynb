# %% [markdown]
# - part 1: https://towardsdatascience.com/how-to-automate-financial-data-collection-with-python-using-tiingo-api-and-google-cloud-platform-b11d8c9afaa1
# - part 2: https://towardsdatascience.com/how-to-process-and-visualize-financial-data-on-google-cloud-with-big-query-data-studio-f37c2417d4ef

# %% [markdown]
# ## Step 1: Obtain list of ticker symbols for securities of interest

# %% [markdown]
# ### 1. Import Relevant Packages

# %%
! pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /Users/anniephan/opt/anaconda3/lib/python3.8/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/anniephan/opt/anaconda3/lib/python3.8/site-packages (from BeautifulSoup4) (2.0.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/anniephan/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url="https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %% [markdown]
# ### 2. Scrape Data

# %%
r = requests.get(url,timeout=2.5)
r_html = r.text
soup = BeautifulSoup(r_html, 'html.parser')
components_table = soup.find_all(id="constituents")
headers_html = soup.find_all("th")
df_columns=[item.text.rstrip("\n") for item in headers_html]

# %% [markdown]
# ### 3. Store data into a Pandas Dataframe

# %%
components_headers=df_columns[:9]
data_rows=components_table[0].find("tbody").find_all("tr")[1:]
rows=[]
for row in range(len(data_rows)):
    
    stock=list(filter(None,data_rows[row].text.split("\n")))
    rows.append(stock)
S_P_500_stocks=pd.DataFrame(rows,columns=components_headers)
S_P_500_stocks.head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM                   3M     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV               AbbVie     reports             Health Care
# 3   ABMD              Abiomed     reports             Health Care
# 4    ACN            Accenture     reports  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#           CIK      Founded
# 0  0000066740         1902
# 1  0000001800         1888
# 2  0001551152  2013 (1888)
# 3  0000815094         1981
# 4  0001467373         1989

# %% [markdown]
# ### 4. Save dataset into csv file

# %%
S_P_500_stocks.drop("SEC filings",inplace=True,axis=1)

# %%
S_P_500_stocks.to_csv(r'/Users/anniephan/Desktop/Data_Science_Master/DATA_1050/Fall_2021/Homework_11/SP500stocks.csv',index=False)

# %% [markdown]
# ## Step 2: Collect historical stock price data using the Tiingo API

# %% [markdown]
# ### 1. Import relevant Packages:

# %%
import requests
import pandas as pd
import datetime
from datetime import datetime,timedelta

# %% [markdown]
# https://api.tiingo.com/documentation/general/overview

# %% [markdown]
# ## 2. Define API Token

# %%
token1 = 'f906fcec2b7ffd5a576f81ff0190758ab5752f35'

# %% [markdown]
# ### 3. Import the SP500 members table

# %%
SP = pd.read_csv(r"/Users/anniephan/Desktop/Data_Science_Master/DATA_1050/Fall_2021/Homework_11/SP500stocks.csv")
SP.head()
# Out:
#   Symbol             Security             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV               AbbVie             Health Care
# 3   ABMD              Abiomed             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#           CIK      Founded
# 0  0000066740         1902
# 1  0000001800         1888
# 2  0001551152  2013 (1888)
# 3  0000815094         1981
# 4  0001467373         1989

# %% [markdown]
# ### 4. Call the Tiingo API and get historical stock price data

# %%
ticker_symbols=list(SP["Symbol"])
ticker_symbols.append("SPY")
end_date=str(datetime.now().date()-timedelta(days=1))
ticker_symbols[:10]
print(end_date)
# Out:
# 2021-11-18

# %%
url = "https://api.tiingo.com/tiingo/daily/{}/prices?startDate=2021-11-01&endDate={}&format=csv&token={}".format('ABBV',end_date,token1)
r = requests.get(url,timeout=10)
#print(r)
rows=r.text.split("\n")[1:-1]
#print(rows)
df=pd.DataFrame(rows)
#print("raw df:",df.head())
df=df.iloc[:,0].str.split(",",13,expand=True)
#print("clean df", df.head())
df["Symbol"]=symbol
#print("symbol df", df.head())
df
# Out:
#              0       1         2       3       4         5       6         7  \
# 0   2021-11-01  114.81    115.72  113.57  115.25   6996715  114.81    115.72
# 1   2021-11-02  116.53    117.69  115.16  115.25  10344882  116.53    117.69
# 2   2021-11-03  117.57    117.61  116.24  116.53   6186916  117.57    117.61
# 3   2021-11-04  117.06    117.72  116.33  117.57   4912212  117.06    117.72
# 4   2021-11-05  117.18  117.3199   115.5  116.73   4635806  117.18  117.3199
# 5   2021-11-08  116.06    117.45  115.78   117.2   7015002  116.06    117.45
# 6   2021-11-09  115.61    116.59  115.41  116.24   3116505  115.61    116.59
# 7   2021-11-10  116.75     117.1  115.39   115.4   4981119  116.75     117.1
# 8   2021-11-11  116.63    117.49  116.29  116.94   3121049  116.63    117.49
# 9   2021-11-12  116.97     117.4  116.43   117.4   2547998  116.97     117.4
# 10  2021-11-15  116.84     117.8  116.22  116.95   3940964  116.84     117.8
# 11  2021-11-16  116.42    117.47  116.34  116.61   3476401  116.42    117.47
# 12  2021-11-17  117.35    117.62  116.25   116.6   4361522  117.35    117.62
# 13  2021-11-18  117.07    118.37  116.64  117.41   3161016  117.07    118.37
#
#          8       9        10   11   12 Symbol
# 0   113.57  115.25   6996715  0.0  1.0    AIZ
# 1   115.16  115.25  10344882  0.0  1.0    AIZ
# 2   116.24  116.53   6186916  0.0  1.0    AIZ
# 3   116.33  117.57   4912212  0.0  1.0    AIZ
# 4    115.5  116.73   4635806  0.0  1.0    AIZ
# 5   115.78   117.2   7015002  0.0  1.0    AIZ
# 6   115.41  116.24   3116505  0.0  1.0    AIZ
# 7   115.39   115.4   4981119  0.0  1.0    AIZ
# 8   116.29  116.94   3121049  0.0  1.0    AIZ
# 9   116.43   117.4   2547998  0.0  1.0    AIZ
# 10  116.22  116.95   3940964  0.0  1.0    AIZ
# 11  116.34  116.61   3476401  0.0  1.0    AIZ
# 12  116.25   116.6   4361522  0.0  1.0    AIZ
# 13  116.64  117.41   3161016  0.0  1.0    AIZ

# %%
data1=[]

for symbol in ticker_symbols[:51]:
    url = "https://api.tiingo.com/tiingo/daily/{}/prices?startDate=2021-01-01&endDate={}&format=csv&token={}".format(symbol,end_date,token1)
    r = requests.get(url,timeout=10)
    #print(r)
    rows=r.text.split("\n")[1:-1]
    #print(rows)
    df=pd.DataFrame(rows)
    #print("raw df:",df.head())
    df=df.iloc[:,0].str.split(",",13,expand=True)
    #print("clean df", df.head())
    df["Symbol"]=symbol
    #print("symbol df", df.head())
    data1.append(df)
data1[:3]
# Out:
# [              0       1       2         3       4        5                 6  \
#  0    2021-01-04  171.87   176.2  170.5504   175.0  2996278  166.545800945774
#  1    2021-01-05  171.58  173.25    170.65  172.01  2295297  166.264784582975
#  2    2021-01-06  174.19  175.57    172.04  172.72  3346410  168.793931848166
#  3    2021-01-07  169.72  173.46    166.16  171.56  5863373  164.462403773298
#  4    2021-01-08  166.62  169.54    164.61  169.17  4808130   161.45843575717
#  ..          ...     ...     ...       ...     ...      ...               ...
#  218  2021-11-12  183.66   186.3   180.285  180.95  4395646   182.15200110957
#  219  2021-11-15  183.31  185.04     182.9  184.09  1463522  181.804874895978
#  220  2021-11-16  183.37   184.2     182.7  183.31  1974979  181.864382246879
#  221  2021-11-17  183.34  183.87    181.63  183.37  2251139  181.834628571429
#  222  2021-11-18  178.77  182.54    178.69  182.11  2522091            178.77
#
#                      7                 8                 9       10    11   12  \
#  0    170.741665948946  165.267079592844  169.578839620122  2996278   0.0  1.0
#  1    167.883051223921  165.363594178136   166.68146401747  2295297   0.0  1.0
#  2    170.131182126313   166.71053467569  167.369469595357  3346410   0.0  1.0
#  3    168.086545831465  161.012685664454  166.245404144161  5863373   0.0  1.0
#  4    164.287979823974   159.51070165639   163.92944170592  4808130   0.0  1.0
#  ..                ...               ...               ...      ...   ...  ...
#  218  184.770324549237  178.804712621359  179.464252427184  4395646   0.0  1.0
#  219  183.520670180305  181.398241331484  182.578470457698  1463522   0.0  1.0
#  220  182.687567267684  181.199883495146  181.804874895978  1974979   0.0  1.0
#  221  182.360276837725  180.138669070735  181.864382246879  2251139   0.0  1.0
#  222            182.54            178.69            182.11  2522091  1.48  1.0
#
#      Symbol
#  0      MMM
#  1      MMM
#  2      MMM
#  3      MMM
#  4      MMM
#  ..     ...
#  218    MMM
#  219    MMM
#  220    MMM
#  221    MMM
#  222    MMM
#
#  [223 rows x 14 columns],
#                0       1        2         3       4        5                 6  \
#  0    2021-01-04  109.11   110.25  107.2551  109.53  6192221  107.439208428065
#  1    2021-01-05  110.46   110.91  108.3038  108.85  4323126  108.768536000038
#  2    2021-01-06  110.23   111.03    108.59  108.95  5539612  108.542057969257
#  3    2021-01-07   111.3   111.62    109.25  110.28  5568900  109.595673155932
#  4    2021-01-08  111.61   112.55  110.3375  111.67  4242160   109.90092615394
#  ..          ...     ...      ...       ...     ...      ...               ...
#  218  2021-11-12  128.45   128.85    127.12  127.94  6441487            128.45
#  219  2021-11-15  129.44  130.195    128.26  128.77  4565941            129.44
#  220  2021-11-16  130.89  131.605    129.64  129.64  4141322            130.89
#  221  2021-11-17  128.62    130.7    128.54  130.61  4759890            128.62
#  222  2021-11-18  127.64   129.43    127.47  129.31  4467001            127.64
#
#                      7                 8                 9       10   11   12  \
#  0    108.561751711064  105.612712344176  107.852777006012  6192221  0.0  1.0
#  1    109.211645190695  106.645353695825  107.183189784575  4323126  0.0  1.0
#  2    109.329807641537  106.927171141084   107.28165849361  5539612  0.0  1.0
#  3    109.910773024843  107.577064620714  108.591292323775  5568900  0.0  1.0
#  4    110.826532018869   108.64791183147  109.960007379361  4242160  0.0  1.0
#  ..                ...               ...               ...      ...  ...  ...
#  218            128.85            127.12            127.94  6441487  0.0  1.0
#  219           130.195            128.26            128.77  4565941  0.0  1.0
#  220           131.605            129.64            129.64  4141322  0.0  1.0
#  221             130.7            128.54            130.61  4759890  0.0  1.0
#  222            129.43            127.47            129.31  4467001  0.0  1.0
#
#      Symbol
#  0      ABT
#  1      ABT
#  2      ABT
#  3      ABT
#  4      ABT
#  ..     ...
#  218    ABT
#  219    ABT
#  220    ABT
#  221    ABT
#  222    ABT
#
#  [223 rows x 14 columns],
#                0       1         2         3       4         5  \
#  0    2021-01-04  105.41    107.35    103.86  107.18   9523377
#  1    2021-01-05   106.5    107.02    104.63  105.41   6823826
#  2    2021-01-06  105.58    107.19    104.18  104.75  11017467
#  3    2021-01-07  106.71  107.0642  105.5663  106.11   8196046
#  4    2021-01-08  107.27    107.53   105.762  106.84   5345883
#  ..          ...     ...       ...       ...     ...       ...
#  218  2021-11-12  116.97     117.4    116.43   117.4   2547998
#  219  2021-11-15  116.84     117.8    116.22  116.95   3940964
#  220  2021-11-16  116.42    117.47    116.34  116.61   3476401
#  221  2021-11-17  117.35    117.62    116.25   116.6   4361522
#  222  2021-11-18  117.07    118.37    116.64  117.41   3161016
#
#                      6                 7                 8                 9  \
#  0    100.604428232965  102.455984923715  99.1250917016956  102.293735110608
#  1     101.64473585818  102.141029404154  99.8599879140036  100.604428232965
#  2    100.766678046072  102.303279217261  99.4305031146029  99.9745171938438
#  3      101.8451620979  102.183214355562  100.753602619957  101.272515698699
#  4    102.379632070488  102.627778843475  100.940380787163  101.969235484394
#  ..                ...               ...               ...               ...
#  218            116.97             117.4            116.43             117.4
#  219            116.84             117.8            116.22            116.95
#  220            116.42            117.47            116.34            116.61
#  221            117.35            117.62            116.25             116.6
#  222            117.07            118.37            116.64            117.41
#
#             10   11   12 Symbol
#  0     9523377  0.0  1.0   ABBV
#  1     6823826  0.0  1.0   ABBV
#  2    11017467  0.0  1.0   ABBV
#  3     8196046  0.0  1.0   ABBV
#  4     5345883  0.0  1.0   ABBV
#  ..        ...  ...  ...    ...
#  218   2547998  0.0  1.0   ABBV
#  219   3940964  0.0  1.0   ABBV
#  220   3476401  0.0  1.0   ABBV
#  221   4361522  0.0  1.0   ABBV
#  222   3161016  0.0  1.0   ABBV
#
#  [223 rows x 14 columns]]

# %%
len(data1)
# Out:
# 51

# %% [markdown]
#  #### debugging

# %%
MMM = data1[0]
MMM.head()
# Out:
#             0       1       2         3       4        5                 6  \
# 0  2021-01-04  171.87   176.2  170.5504   175.0  2996278  166.545800945774
# 1  2021-01-05  171.58  173.25    170.65  172.01  2295297  166.264784582975
# 2  2021-01-06  174.19  175.57    172.04  172.72  3346410  168.793931848166
# 3  2021-01-07  169.72  173.46    166.16  171.56  5863373  164.462403773298
# 4  2021-01-08  166.62  169.54    164.61  169.17  4808130   161.45843575717
#
#                   7                 8                 9       10   11   12  \
# 0  170.741665948946  165.267079592844  169.578839620122  2996278  0.0  1.0
# 1  167.883051223921  165.363594178136   166.68146401747  2295297  0.0  1.0
# 2  170.131182126313   166.71053467569  167.369469595357  3346410  0.0  1.0
# 3  168.086545831465  161.012685664454  166.245404144161  5863373  0.0  1.0
# 4  164.287979823974   159.51070165639   163.92944170592  4808130  0.0  1.0
#
#   Symbol
# 0    MMM
# 1    MMM
# 2    MMM
# 3    MMM
# 4    MMM

# %%
MMM.shape
# Out:
# (223, 14)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
MMM.dtypes
# Out:
# 0         object
# 1         object
# 2         object
# 3         object
# 4         object
# 5         object
# 6         object
# 7         object
# 8         object
# 9         object
# 10        object
# 11        object
# 12        object
# Symbol    object
# dtype: object

# %%
MMM.drop(MMM.columns[[5,10,11,12]], axis=1, inplace=True) 
MMM.head()
# Out:
#             0       1       2         3       4                 6  \
# 0  2021-01-04  171.87   176.2  170.5504   175.0  166.545800945774
# 1  2021-01-05  171.58  173.25    170.65  172.01  166.264784582975
# 2  2021-01-06  174.19  175.57    172.04  172.72  168.793931848166
# 3  2021-01-07  169.72  173.46    166.16  171.56  164.462403773298
# 4  2021-01-08  166.62  169.54    164.61  169.17   161.45843575717
#
#                   7                 8                 9 Symbol
# 0  170.741665948946  165.267079592844  169.578839620122    MMM
# 1  167.883051223921  165.363594178136   166.68146401747    MMM
# 2  170.131182126313   166.71053467569  167.369469595357    MMM
# 3  168.086545831465  161.012685664454  166.245404144161    MMM
# 4  164.287979823974   159.51070165639   163.92944170592    MMM

# %%
MMM[[1,2,3,4,6,7,8,9]] = MMM[[1,2,3,4,6,7,8,9]].apply(pd.to_numeric)
MMM.head()
# Out:
#             0       1       2         3       4           6           7  \
# 0  2021-01-04  171.87  176.20  170.5504  175.00  166.545801  170.741666
# 1  2021-01-05  171.58  173.25  170.6500  172.01  166.264785  167.883051
# 2  2021-01-06  174.19  175.57  172.0400  172.72  168.793932  170.131182
# 3  2021-01-07  169.72  173.46  166.1600  171.56  164.462404  168.086546
# 4  2021-01-08  166.62  169.54  164.6100  169.17  161.458436  164.287980
#
#             8           9 Symbol
# 0  165.267080  169.578840    MMM
# 1  165.363594  166.681464    MMM
# 2  166.710535  167.369470    MMM
# 3  161.012686  166.245404    MMM
# 4  159.510702  163.929442    MMM

# %%
MMM[0]= pd.to_datetime(MMM[0])
MMM.dtypes
# Out:
# 0         datetime64[ns]
# 1                float64
# 2                float64
# 3                float64
# 4                float64
# 6                float64
# 7                float64
# 8                float64
# 9                float64
# Symbol            object
# dtype: object

# %%
MMM.head()
# Out:
#            0       1       2         3       4           6           7  \
# 0 2021-01-04  171.87  176.20  170.5504  175.00  166.545801  170.741666
# 1 2021-01-05  171.58  173.25  170.6500  172.01  166.264785  167.883051
# 2 2021-01-06  174.19  175.57  172.0400  172.72  168.793932  170.131182
# 3 2021-01-07  169.72  173.46  166.1600  171.56  164.462404  168.086546
# 4 2021-01-08  166.62  169.54  164.6100  169.17  161.458436  164.287980
#
#             8           9 Symbol
# 0  165.267080  169.578840    MMM
# 1  165.363594  166.681464    MMM
# 2  166.710535  167.369470    MMM
# 3  161.012686  166.245404    MMM
# 4  159.510702  163.929442    MMM

# %%
MMM['mean_price_everyday'] = MMM.iloc[:, 1:9].mean(axis=1)
MMM.head()
# Out:
#            0       1       2         3       4           6           7  \
# 0 2021-01-04  171.87  176.20  170.5504  175.00  166.545801  170.741666
# 1 2021-01-05  171.58  173.25  170.6500  172.01  166.264785  167.883051
# 2 2021-01-06  174.19  175.57  172.0400  172.72  168.793932  170.131182
# 3 2021-01-07  169.72  173.46  166.1600  171.56  164.462404  168.086546
# 4 2021-01-08  166.62  169.54  164.6100  169.17  161.458436  164.287980
#
#             8           9 Symbol  mean_price_everyday
# 0  165.267080  169.578840    MMM           170.719223
# 1  165.363594  166.681464    MMM           169.210362
# 2  166.710535  167.369470    MMM           170.940640
# 3  161.012686  166.245404    MMM           167.588380
# 4  159.510702  163.929442    MMM           164.890820

# %%
MMM_ = MMM.groupby(pd.PeriodIndex(MMM[0], freq="M"))['mean_price_everyday'].mean().reset_index()
MMM_.rename(columns={0: 'year-month', 'mean_price_everyday': 'mean_price_month' }, inplace=True)
MMM_
# Out:
#    year-month  mean_price_month
# 0     2021-01        168.634545
# 1     2021-02        175.314258
# 2     2021-03        184.209234
# 3     2021-04        194.874722
# 4     2021-05        200.248844
# 5     2021-06        197.669134
# 6     2021-07        197.960193
# 7     2021-08        196.316500
# 8     2021-09        183.647625
# 9     2021-10        178.505038
# 10    2021-11        181.110754

# %%
MMM_['7day_ave'] = MMM_['mean_price_month'].rolling(2).mean()
MMM_
# Out:
#    year-month  mean_price_month    7day_ave
# 0     2021-01        168.634545         NaN
# 1     2021-02        175.314258  171.974401
# 2     2021-03        184.209234  179.761746
# 3     2021-04        194.874722  189.541978
# 4     2021-05        200.248844  197.561783
# 5     2021-06        197.669134  198.958989
# 6     2021-07        197.960193  197.814664
# 7     2021-08        196.316500  197.138347
# 8     2021-09        183.647625  189.982063
# 9     2021-10        178.505038  181.076332
# 10    2021-11        181.110754  179.807896

# %%
MMM_["Symbol"] = MMM["Symbol"].values[:11]

# %%
MMM_
# Out:
#    year-month  mean_price_month Symbol
# 0     2021-01        168.634545    MMM
# 1     2021-02        175.314258    MMM
# 2     2021-03        184.209234    MMM
# 3     2021-04        194.874722    MMM
# 4     2021-05        200.248844    MMM
# 5     2021-06        197.669134    MMM
# 6     2021-07        197.960193    MMM
# 7     2021-08        196.316500    MMM
# 8     2021-09        183.647625    MMM
# 9     2021-10        178.505038    MMM
# 10    2021-11        181.110754    MMM

# %%
MMM
# Out:
#              0       1       2         3       4           6           7  \
# 0   2021-01-04  171.87  176.20  170.5504  175.00  166.545801  170.741666
# 1   2021-01-05  171.58  173.25  170.6500  172.01  166.264785  167.883051
# 2   2021-01-06  174.19  175.57  172.0400  172.72  168.793932  170.131182
# 3   2021-01-07  169.72  173.46  166.1600  171.56  164.462404  168.086546
# 4   2021-01-08  166.62  169.54  164.6100  169.17  161.458436  164.287980
# ..         ...     ...     ...       ...     ...         ...         ...
# 218 2021-11-12  183.66  186.30  180.2850  180.95  182.152001  184.770325
# 219 2021-11-15  183.31  185.04  182.9000  184.09  181.804875  183.520670
# 220 2021-11-16  183.37  184.20  182.7000  183.31  181.864382  182.687567
# 221 2021-11-17  183.34  183.87  181.6300  183.37  181.834629  182.360277
# 222 2021-11-18  178.77  182.54  178.6900  182.11  178.770000  182.540000
#
#               8           9 Symbol  mean_price_everyday
# 0    165.267080  169.578840    MMM           170.719223
# 1    165.363594  166.681464    MMM           169.210362
# 2    166.710535  167.369470    MMM           170.940640
# 3    161.012686  166.245404    MMM           167.588380
# 4    159.510702  163.929442    MMM           164.890820
# ..          ...         ...    ...                  ...
# 218  178.804713  179.464252    MMM           182.048286
# 219  181.398241  182.578470    MMM           183.080282
# 220  181.199883  181.804875    MMM           182.642088
# 221  180.138669  181.864382    MMM           182.300995
# 222  178.690000  182.110000    MMM           180.527500
#
# [223 rows x 11 columns]

# %%
MMM['mean'].hist()

# %% [markdown]
# #### debug 2

# %%
ABT = data1[1]
ABT.head()
# Out:
#             0       1       2         3       4        5                 6  \
# 0  2021-01-04  109.11  110.25  107.2551  109.53  6192221  107.439208428065
# 1  2021-01-05  110.46  110.91  108.3038  108.85  4323126  108.768536000038
# 2  2021-01-06  110.23  111.03    108.59  108.95  5539612  108.542057969257
# 3  2021-01-07   111.3  111.62    109.25  110.28  5568900  109.595673155932
# 4  2021-01-08  111.61  112.55  110.3375  111.67  4242160   109.90092615394
#
#                   7                 8                 9       10   11   12  \
# 0  108.561751711064  105.612712344176  107.852777006012  6192221  0.0  1.0
# 1  109.211645190695  106.645353695825  107.183189784575  4323126  0.0  1.0
# 2  109.329807641537  106.927171141084   107.28165849361  5539612  0.0  1.0
# 3  109.910773024843  107.577064620714  108.591292323775  5568900  0.0  1.0
# 4  110.826532018869   108.64791183147  109.960007379361  4242160  0.0  1.0
#
#   Symbol
# 0    ABT
# 1    ABT
# 2    ABT
# 3    ABT
# 4    ABT

# %%
ABT.shape
# Out:
# (223, 14)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
ABT.dtypes
# Out:
# 0         object
# 1         object
# 2         object
# 3         object
# 4         object
# 5         object
# 6         object
# 7         object
# 8         object
# 9         object
# 10        object
# 11        object
# 12        object
# Symbol    object
# dtype: object

# %%
ABT.drop(ABT.columns[[5,10,11,12]], axis=1, inplace=True) 
ABT.head()
# Out:
#             0       1       2         3       4                 6  \
# 0  2021-01-04  109.11  110.25  107.2551  109.53  107.439208428065
# 1  2021-01-05  110.46  110.91  108.3038  108.85  108.768536000038
# 2  2021-01-06  110.23  111.03    108.59  108.95  108.542057969257
# 3  2021-01-07   111.3  111.62    109.25  110.28  109.595673155932
# 4  2021-01-08  111.61  112.55  110.3375  111.67   109.90092615394
#
#                   7                 8                 9 Symbol
# 0  108.561751711064  105.612712344176  107.852777006012    ABT
# 1  109.211645190695  106.645353695825  107.183189784575    ABT
# 2  109.329807641537  106.927171141084   107.28165849361    ABT
# 3  109.910773024843  107.577064620714  108.591292323775    ABT
# 4  110.826532018869   108.64791183147  109.960007379361    ABT

# %%
ABT[[1,2,3,4,6,7,8,9]] = ABT[[1,2,3,4,6,7,8,9]].apply(pd.to_numeric)
ABT.head()
# Out:
#             0       1       2         3       4           6           7  \
# 0  2021-01-04  109.11  110.25  107.2551  109.53  107.439208  108.561752
# 1  2021-01-05  110.46  110.91  108.3038  108.85  108.768536  109.211645
# 2  2021-01-06  110.23  111.03  108.5900  108.95  108.542058  109.329808
# 3  2021-01-07  111.30  111.62  109.2500  110.28  109.595673  109.910773
# 4  2021-01-08  111.61  112.55  110.3375  111.67  109.900926  110.826532
#
#             8           9 Symbol
# 0  105.612712  107.852777    ABT
# 1  106.645354  107.183190    ABT
# 2  106.927171  107.281658    ABT
# 3  107.577065  108.591292    ABT
# 4  108.647912  109.960007    ABT

# %%
ABT[0]= pd.to_datetime(ABT[0])
ABT.dtypes
# Out:
# 0         datetime64[ns]
# 1                float64
# 2                float64
# 3                float64
# 4                float64
# 6                float64
# 7                float64
# 8                float64
# 9                float64
# Symbol            object
# dtype: object

# %%
ABT.head()
# Out:
#            0       1       2         3       4           6           7  \
# 0 2021-01-04  109.11  110.25  107.2551  109.53  107.439208  108.561752
# 1 2021-01-05  110.46  110.91  108.3038  108.85  108.768536  109.211645
# 2 2021-01-06  110.23  111.03  108.5900  108.95  108.542058  109.329808
# 3 2021-01-07  111.30  111.62  109.2500  110.28  109.595673  109.910773
# 4 2021-01-08  111.61  112.55  110.3375  111.67  109.900926  110.826532
#
#             8           9 Symbol
# 0  105.612712  107.852777    ABT
# 1  106.645354  107.183190    ABT
# 2  106.927171  107.281658    ABT
# 3  107.577065  108.591292    ABT
# 4  108.647912  109.960007    ABT

# %%
ABT.iloc[:, 1:9]
# Out:
#           1        2         3       4           6           7           8  \
# 0    109.11  110.250  107.2551  109.53  107.439208  108.561752  105.612712
# 1    110.46  110.910  108.3038  108.85  108.768536  109.211645  106.645354
# 2    110.23  111.030  108.5900  108.95  108.542058  109.329808  106.927171
# 3    111.30  111.620  109.2500  110.28  109.595673  109.910773  107.577065
# 4    111.61  112.550  110.3375  111.67  109.900926  110.826532  108.647912
# ..      ...      ...       ...     ...         ...         ...         ...
# 218  128.45  128.850  127.1200  127.94  128.450000  128.850000  127.120000
# 219  129.44  130.195  128.2600  128.77  129.440000  130.195000  128.260000
# 220  130.89  131.605  129.6400  129.64  130.890000  131.605000  129.640000
# 221  128.62  130.700  128.5400  130.61  128.620000  130.700000  128.540000
# 222  127.64  129.430  127.4700  129.31  127.640000  129.430000  127.470000
#
#               9
# 0    107.852777
# 1    107.183190
# 2    107.281658
# 3    108.591292
# 4    109.960007
# ..          ...
# 218  127.940000
# 219  128.770000
# 220  129.640000
# 221  130.610000
# 222  129.310000
#
# [223 rows x 8 columns]

# %%
ABT['mean_price_everyday'] = ABT.iloc[:, 1:9].mean(axis=1)
ABT.head()
# Out:
#            0       1       2         3       4           6           7  \
# 0 2021-01-04  109.11  110.25  107.2551  109.53  107.439208  108.561752
# 1 2021-01-05  110.46  110.91  108.3038  108.85  108.768536  109.211645
# 2 2021-01-06  110.23  111.03  108.5900  108.95  108.542058  109.329808
# 3 2021-01-07  111.30  111.62  109.2500  110.28  109.595673  109.910773
# 4 2021-01-08  111.61  112.55  110.3375  111.67  109.900926  110.826532
#
#             8           9 Symbol  mean_price_everyday
# 0  105.612712  107.852777    ABT           108.201444
# 1  106.645354  107.183190    ABT           108.791566
# 2  106.927171  107.281658    ABT           108.860087
# 3  107.577065  108.591292    ABT           109.765600
# 4  108.647912  109.960007    ABT           110.687860

# %%
ABT['7day_ave'] = ABT['mean_price_everyday'].rolling(7).mean()
ABT
# Out:
#              0       1        2         3       4           6           7  \
# 0   2021-01-04  109.11  110.250  107.2551  109.53  107.439208  108.561752
# 1   2021-01-05  110.46  110.910  108.3038  108.85  108.768536  109.211645
# 2   2021-01-06  110.23  111.030  108.5900  108.95  108.542058  109.329808
# 3   2021-01-07  111.30  111.620  109.2500  110.28  109.595673  109.910773
# 4   2021-01-08  111.61  112.550  110.3375  111.67  109.900926  110.826532
# ..         ...     ...      ...       ...     ...         ...         ...
# 218 2021-11-12  128.45  128.850  127.1200  127.94  128.450000  128.850000
# 219 2021-11-15  129.44  130.195  128.2600  128.77  129.440000  130.195000
# 220 2021-11-16  130.89  131.605  129.6400  129.64  130.890000  131.605000
# 221 2021-11-17  128.62  130.700  128.5400  130.61  128.620000  130.700000
# 222 2021-11-18  127.64  129.430  127.4700  129.31  127.640000  129.430000
#
#               8           9 Symbol  mean_price_everyday    7day_ave
# 0    105.612712  107.852777    ABT           108.201444         NaN
# 1    106.645354  107.183190    ABT           108.791566         NaN
# 2    106.927171  107.281658    ABT           108.860087         NaN
# 3    107.577065  108.591292    ABT           109.765600         NaN
# 4    108.647912  109.960007    ABT           110.687860         NaN
# ..          ...         ...    ...                  ...         ...
# 218  127.120000  127.940000    ABT           128.090000  127.110357
# 219  128.260000  128.770000    ABT           129.166250  127.144107
# 220  129.640000  129.640000    ABT           130.443750  127.825357
# 221  128.540000  130.610000    ABT           129.617500  128.419286
# 222  127.470000  129.310000    ABT           128.462500  128.668214
#
# [223 rows x 12 columns]

# %%
ABT.rename(columns={0: 'ymd'}, inplace=True)
ABT
# Out:
#            ymd       1        2         3       4           6           7  \
# 0   2021-01-04  109.11  110.250  107.2551  109.53  107.439208  108.561752
# 1   2021-01-05  110.46  110.910  108.3038  108.85  108.768536  109.211645
# 2   2021-01-06  110.23  111.030  108.5900  108.95  108.542058  109.329808
# 3   2021-01-07  111.30  111.620  109.2500  110.28  109.595673  109.910773
# 4   2021-01-08  111.61  112.550  110.3375  111.67  109.900926  110.826532
# ..         ...     ...      ...       ...     ...         ...         ...
# 218 2021-11-12  128.45  128.850  127.1200  127.94  128.450000  128.850000
# 219 2021-11-15  129.44  130.195  128.2600  128.77  129.440000  130.195000
# 220 2021-11-16  130.89  131.605  129.6400  129.64  130.890000  131.605000
# 221 2021-11-17  128.62  130.700  128.5400  130.61  128.620000  130.700000
# 222 2021-11-18  127.64  129.430  127.4700  129.31  127.640000  129.430000
#
#               8           9 Symbol  mean_price_everyday    7day_ave
# 0    105.612712  107.852777    ABT           108.201444         NaN
# 1    106.645354  107.183190    ABT           108.791566         NaN
# 2    106.927171  107.281658    ABT           108.860087         NaN
# 3    107.577065  108.591292    ABT           109.765600         NaN
# 4    108.647912  109.960007    ABT           110.687860         NaN
# ..          ...         ...    ...                  ...         ...
# 218  127.120000  127.940000    ABT           128.090000  127.110357
# 219  128.260000  128.770000    ABT           129.166250  127.144107
# 220  129.640000  129.640000    ABT           130.443750  127.825357
# 221  128.540000  130.610000    ABT           129.617500  128.419286
# 222  127.470000  129.310000    ABT           128.462500  128.668214
#
# [223 rows x 12 columns]

# %%
ABT = ABT[['ymd', '7day_ave', 'Symbol']]
ABT
# Out:
#            ymd    7day_ave Symbol
# 0   2021-01-04         NaN    ABT
# 1   2021-01-05         NaN    ABT
# 2   2021-01-06         NaN    ABT
# 3   2021-01-07         NaN    ABT
# 4   2021-01-08         NaN    ABT
# ..         ...         ...    ...
# 218 2021-11-12  127.110357    ABT
# 219 2021-11-15  127.144107    ABT
# 220 2021-11-16  127.825357    ABT
# 221 2021-11-17  128.419286    ABT
# 222 2021-11-18  128.668214    ABT
#
# [223 rows x 3 columns]

# %%
ABT['7day_ave'][0:13]
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6     109.326612
# 7     109.547937
# 8     109.726358
# 9     109.882560
# 10    110.110051
# 11    110.316235
# 12    110.516613
# Name: 7day_ave, dtype: float64

# %%
sns.lineplot(x="ymd",y="7day_ave",
             label="7-day Ave",
             data=ABT,
             ci=None)

# %% [markdown]
# #### back to real code

# %% [markdown]
# #### monthly average

# %%
range(len(data1))
# Out:
# range(0, 51)

# %% [markdown]
# new_data = []
# for index in range(len(data1)):
#     print(index)
#     sub_data=data1[index]
#     sub_data.drop(sub_data.columns[[5,10,11,12]], axis=1, inplace=True)
#     sub_data[[1,2,3,4,6,7,8,9]] = sub_data[[1,2,3,4,6,7,8,9]].apply(pd.to_numeric)
#     sub_data['mean'] = sub_data.iloc[:, 1:8].mean(axis=1)
#     sub_data = sub_data[[0, "Symbol", "mean"]]
#     print(sub_data.head())
#     new_data.append(sub_data)
# new_data[:3]

# %%
new_data = []
for index in range(len(data1)):
    print(index)
    sub_data=data1[index]
    sub_data.drop(sub_data.columns[[5,10,11,12]], axis=1, inplace=True) 
    sub_data[[1,2,3,4,6,7,8,9]] = sub_data[[1,2,3,4,6,7,8,9]].apply(pd.to_numeric)
    sub_data[0]= pd.to_datetime(sub_data[0])
    sub_data['mean_price_everyday'] = sub_data.iloc[:, 1:9].mean(axis=1)
    sub_data_month = sub_data.groupby(pd.PeriodIndex(sub_data[0], freq="M"))['mean_price_everyday'].mean().reset_index()
    sub_data_month.rename(columns={0: 'year-month', 'mean_price_everyday': 'mean_price_month' }, inplace=True)
    sub_data_month["Symbol"] = sub_data["Symbol"].values[:11]
    print(sub_data_month.head())
    new_data.append(sub_data_month)
new_data[:3]
# Out:
# 0
#   year-month  mean_price_month Symbol
# 0    2021-01        168.634545    MMM
# 1    2021-02        175.314258    MMM
# 2    2021-03        184.209234    MMM
# 3    2021-04        194.874722    MMM
# 4    2021-05        200.248844    MMM
# 1
#   year-month  mean_price_month Symbol
# 0    2021-01        111.822508    ABT
# 1    2021-02        122.911080    ABT
# 2    2021-03        118.324152    ABT
# 3    2021-04        121.033387    ABT
# 4    2021-05        117.348286    ABT
# 2
#   year-month  mean_price_month Symbol
# 0    2021-01        106.306940   ABBV
# 1    2021-02        104.102500   ABBV
# 2    2021-03        104.588965   ABBV
# 3    2021-04        107.164648   ABBV
# 4    2021-05        114.180284   ABBV
# 3
#   year-month  mean_price_month Symbol
# 0    2021-01        332.991220   ABMD
# 1    2021-02        326.382542   ABMD
# 2    2021-03        303.973171   ABMD
# 3    2021-04        332.870689   ABMD
# 4    2021-05        283.938579   ABMD
# 4
#   year-month  mean_price_month Symbol
# 0    2021-01        254.848560    ACN
# 1    2021-02        253.394607    ACN
# 2    2021-03        262.476987    ACN
# 3    2021-04        285.688349    ACN
# 4    2021-05        285.680160    ACN
# 5
#   year-month  mean_price_month Symbol
# 0    2021-01         91.076606   ATVI
# 1    2021-02         98.485229   ATVI
# 2    2021-03         92.369249   ATVI
# 3    2021-04         94.974644   ATVI
# 4    2021-05         94.210054   ATVI
# 6
#   year-month  mean_price_month Symbol
# 0    2021-01        471.387959   ADBE
# 1    2021-02        482.878113   ADBE
# 2    2021-03        451.871058   ADBE
# 3    2021-04        507.919671   ADBE
# 4    2021-05        490.010524   ADBE
# 7
#   year-month  mean_price_month Symbol
# 0    2021-01         91.924076    AMD
# 1    2021-02         88.577057    AMD
# 2    2021-03         79.559154    AMD
# 3    2021-04         81.993095    AMD
# 4    2021-05         76.927506    AMD
# 8
#   year-month  mean_price_month Symbol
# 0    2021-01        162.291411    AAP
# 1    2021-02        158.821126    AAP
# 2    2021-03        176.663062    AAP
# 3    2021-04        190.609615    AAP
# 4    2021-05        198.219268    AAP
# 9
#   year-month  mean_price_month Symbol
# 0    2021-01         25.436889    AES
# 1    2021-02         26.975579    AES
# 2    2021-03         26.523790    AES
# 3    2021-04         27.717843    AES
# 4    2021-05         25.409111    AES
# 10
#   year-month  mean_price_month Symbol
# 0    2021-01         45.077384    AFL
# 1    2021-02         46.629357    AFL
# 2    2021-03         50.133012    AFL
# 3    2021-04         52.250135    AFL
# 4    2021-05         55.352161    AFL
# 11
#   year-month  mean_price_month Symbol
# 0    2021-01        124.387888      A
# 1    2021-02        124.732569      A
# 2    2021-03        121.639744      A
# 3    2021-04        132.729247      A
# 4    2021-05        132.174192      A
# 12
#   year-month  mean_price_month Symbol
# 0    2021-01        279.556357    APD
# 1    2021-02        259.278594    APD
# 2    2021-03        270.113273    APD
# 3    2021-04        285.071460    APD
# 4    2021-05        295.314292    APD
# 13
#   year-month  mean_price_month Symbol
# 0    2021-01        107.614974   AKAM
# 1    2021-02        104.891699   AKAM
# 2    2021-03         98.532045   AKAM
# 3    2021-04        105.771250   AKAM
# 4    2021-05        111.863787   AKAM
# 14
#   year-month  mean_price_month Symbol
# 0    2021-01         52.113461    ALK
# 1    2021-02         58.494234    ALK
# 2    2021-03         67.779507    ALK
# 3    2021-04         69.947779    ALK
# 4    2021-05         68.282885    ALK
# 15
#   year-month  mean_price_month Symbol
# 0    2021-01        174.237266    ALB
# 1    2021-02        157.948991    ALB
# 2    2021-03        150.243494    ALB
# 3    2021-04        154.880791    ALB
# 4    2021-05        160.152287    ALB
# 16
#   year-month  mean_price_month Symbol
# 0    2021-01        166.339218    ARE
# 1    2021-02        166.974908    ARE
# 2    2021-03        162.850066    ARE
# 3    2021-04        173.465371    ARE
# 4    2021-05        175.315945    ARE
# 17
#   year-month  mean_price_month Symbol
# 0    2021-01        545.648461   ALGN
# 1    2021-02        587.951066   ALGN
# 2    2021-03        530.976235   ALGN
# 3    2021-04        594.254879   ALGN
# 4    2021-05        579.607011   ALGN
# 18
#   year-month  mean_price_month Symbol
# 0    2021-01        114.768862   ALLE
# 1    2021-02        111.460572   ALLE
# 2    2021-03        118.139583   ALLE
# 3    2021-04        132.613988   ALLE
# 4    2021-05        138.352930   ALLE
# 19
#   year-month  mean_price_month Symbol
# 0    2021-01         48.742077    LNT
# 1    2021-02         48.016901    LNT
# 2    2021-03         50.496821    LNT
# 3    2021-04         54.871026    LNT
# 4    2021-05         56.670142    LNT
# 20
#   year-month  mean_price_month Symbol
# 0    2021-01        108.552082    ALL
# 1    2021-02        105.672148    ALL
# 2    2021-03        112.920156    ALL
# 3    2021-04        120.676218    ALL
# 4    2021-05        133.584869    ALL
# 21
#   year-month  mean_price_month Symbol
# 0    2021-01       1798.377957  GOOGL
# 1    2021-02       2055.225821  GOOGL
# 2    2021-03       2048.986083  GOOGL
# 3    2021-04       2271.125258  GOOGL
# 4    2021-05       2308.220920  GOOGL
# 22
#   year-month  mean_price_month Symbol
# 0    2021-01       1805.902370   GOOG
# 1    2021-02       2065.239521   GOOG
# 2    2021-03       2061.090792   GOOG
# 3    2021-04       2287.203224   GOOG
# 4    2021-05       2352.385611   GOOG
# 23
#   year-month  mean_price_month Symbol
# 0    2021-01         40.446193     MO
# 1    2021-02         42.131323     MO
# 2    2021-03         47.492608     MO
# 3    2021-04         48.632767     MO
# 4    2021-05         48.726398     MO
# 24
#   year-month  mean_price_month Symbol
# 0    2021-01       3204.866657   AMZN
# 1    2021-02       3265.379279   AMZN
# 2    2021-03       3071.074962   AMZN
# 3    2021-04       3350.899701   AMZN
# 4    2021-05       3253.649001   AMZN
# 25
#   year-month  mean_price_month Symbol
# 0    2021-01         11.142462   AMCR
# 1    2021-02         11.128579   AMCR
# 2    2021-03         11.433718   AMCR
# 3    2021-04         11.661005   AMCR
# 4    2021-05         12.025647   AMCR
# 26
#   year-month  mean_price_month Symbol
# 0    2021-01         73.669471    AEE
# 1    2021-02         72.040528    AEE
# 2    2021-03         76.492503    AEE
# 3    2021-04         82.523457    AEE
# 4    2021-05         83.791284    AEE
# 27
#   year-month  mean_price_month Symbol
# 0    2021-01         15.931392    AAL
# 1    2021-02         18.338133    AAL
# 2    2021-03         22.843140    AAL
# 3    2021-04         22.319392    AAL
# 4    2021-05         22.445113    AAL
# 28
#   year-month  mean_price_month Symbol
# 0    2021-01         79.020582    AEP
# 1    2021-02         78.351778    AEP
# 2    2021-03         80.538180    AEP
# 3    2021-04         86.158706    AEP
# 4    2021-05         85.873118    AEP
# 29
#   year-month  mean_price_month Symbol
# 0    2021-01        121.166084    AXP
# 1    2021-02        128.358917    AXP
# 2    2021-03        142.607389    AXP
# 3    2021-04        147.352140    AXP
# 4    2021-05        156.139011    AXP
# 30
#   year-month  mean_price_month Symbol
# 0    2021-01         39.571499    AIG
# 1    2021-02         41.601575    AIG
# 2    2021-03         46.513503    AIG
# 3    2021-04         46.776185    AIG
# 4    2021-05         50.496963    AIG
# 31
#   year-month  mean_price_month Symbol
# 0    2021-01        219.665639    AMT
# 1    2021-02        226.977616    AMT
# 2    2021-03        217.135418    AMT
# 3    2021-04        245.786971    AMT
# 4    2021-05        247.624720    AMT
# 32
#   year-month  mean_price_month Symbol
# 0    2021-01        156.256702    AWK
# 1    2021-02        158.346035    AWK
# 2    2021-03        139.801394    AWK
# 3    2021-04        155.034171    AWK
# 4    2021-05        152.981983    AWK
# 33
#   year-month  mean_price_month Symbol
# 0    2021-01        202.335405    AMP
# 1    2021-02        214.345876    AMP
# 2    2021-03        224.849403    AMP
# 3    2021-04        244.106633    AMP
# 4    2021-05        256.042382    AMP
# 34
#   year-month  mean_price_month Symbol
# 0    2021-01        104.742705    ABC
# 1    2021-02        105.413261    ABC
# 2    2021-03        111.276547    ABC
# 3    2021-04        118.009753    ABC
# 4    2021-05        118.284859    ABC
# 35
#   year-month  mean_price_month Symbol
# 0    2021-01        119.026945    AME
# 1    2021-02        119.147773    AME
# 2    2021-03        122.740918    AME
# 3    2021-04        132.246688    AME
# 4    2021-05        134.039905    AME
# 36
#   year-month  mean_price_month Symbol
# 0    2021-01        239.261671   AMGN
# 1    2021-02        231.751942   AMGN
# 2    2021-03        235.068200   AMGN
# 3    2021-04        247.465433   AMGN
# 4    2021-05        246.090286   AMGN
# 37
#   year-month  mean_price_month Symbol
# 0    2021-01         98.777206    APH
# 1    2021-02         97.362368    APH
# 2    2021-03         69.337473    APH
# 3    2021-04         67.824680    APH
# 4    2021-05         66.382605    APH
# 38
#   year-month  mean_price_month Symbol
# 0    2021-01        153.760607    ADI
# 1    2021-02        154.547105    ADI
# 2    2021-03        150.810904    ADI
# 3    2021-04        158.212723    ADI
# 4    2021-05        154.140931    ADI
# 39
#   year-month  mean_price_month Symbol
# 0    2021-01        366.333218   ANSS
# 1    2021-02        380.311495   ANSS
# 2    2021-03        325.649987   ANSS
# 3    2021-04        366.558726   ANSS
# 4    2021-05        333.979365   ANSS
# 40
#   year-month  mean_price_month Symbol
# 0    2021-01        319.176716   ANTM
# 1    2021-02        295.026630   ANTM
# 2    2021-03        341.633674   ANTM
# 3    2021-04        367.901836   ANTM
# 4    2021-05        392.448846   ANTM
# 41
#   year-month  mean_price_month Symbol
# 0    2021-01        206.067097    AON
# 1    2021-02        222.897686    AON
# 2    2021-03        227.596349    AON
# 3    2021-04        234.992431    AON
# 4    2021-05        253.472926    AON
# 42
#   year-month  mean_price_month Symbol
# 0    2021-01         56.047974    AOS
# 1    2021-02         59.342270    AOS
# 2    2021-03         64.811952    AOS
# 3    2021-04         67.369409    AOS
# 4    2021-05         70.036557    AOS
# 43
#   year-month  mean_price_month Symbol
# 0    2021-01         16.488557    APA
# 1    2021-02         17.729273    APA
# 2    2021-03         20.034862    APA
# 3    2021-04         18.144251    APA
# 4    2021-05         20.926494    APA
# 44
#   year-month  mean_price_month Symbol
# 0    2021-01        132.639353   AAPL
# 1    2021-02        131.311297   AAPL
# 2    2021-03        121.675891   AAPL
# 3    2021-04        131.410059   AAPL
# 4    2021-05        126.740749   AAPL
# 45
#   year-month  mean_price_month Symbol
# 0    2021-01         99.997061   AMAT
# 1    2021-02        110.545875   AMAT
# 2    2021-03        117.919306   AMAT
# 3    2021-04        135.847682   AMAT
# 4    2021-05        128.464013   AMAT
# 46
#   year-month  mean_price_month Symbol
# 0    2021-01        140.120489   APTV
# 1    2021-02        149.552005   APTV
# 2    2021-03        146.427348   APTV
# 3    2021-04        142.200774   APTV
# 4    2021-05        141.311971   APTV
# 47
#   year-month  mean_price_month Symbol
# 0    2021-01         51.354953    ADM
# 1    2021-02         54.230386    ADM
# 2    2021-03         56.885055    ADM
# 3    2021-04         58.853966    ADM
# 4    2021-05         66.095356    ADM
# 48
#   year-month  mean_price_month Symbol
# 0    2021-01        191.031473   ANET
# 1    2021-02        193.319531   ANET
# 2    2021-03        178.408696   ANET
# 3    2021-04        196.483865   ANET
# 4    2021-05        204.094297   ANET
# 49
#   year-month  mean_price_month Symbol
# 0    2021-01        117.661696    AJG
# 1    2021-02        117.878734    AJG
# 2    2021-03        124.009200    AJG
# 3    2021-04        134.135760    AJG
# 4    2021-05        146.119808    AJG
# 50
#   year-month  mean_price_month Symbol
# 0    2021-01        135.925727    AIZ
# 1    2021-02        128.723699    AIZ
# 2    2021-03        136.763835    AIZ
# 3    2021-04        149.880227    AIZ
# 4    2021-05        158.333110    AIZ
# [   year-month  mean_price_month Symbol
#  0     2021-01        168.634545    MMM
#  1     2021-02        175.314258    MMM
#  2     2021-03        184.209234    MMM
#  3     2021-04        194.874722    MMM
#  4     2021-05        200.248844    MMM
#  5     2021-06        197.669134    MMM
#  6     2021-07        197.960193    MMM
#  7     2021-08        196.316500    MMM
#  8     2021-09        183.647625    MMM
#  9     2021-10        178.505038    MMM
#  10    2021-11        181.110754    MMM,
#     year-month  mean_price_month Symbol
#  0     2021-01        111.822508    ABT
#  1     2021-02        122.911080    ABT
#  2     2021-03        118.324152    ABT
#  3     2021-04        121.033387    ABT
#  4     2021-05        117.348286    ABT
#  5     2021-06        110.343642    ABT
#  6     2021-07        118.480187    ABT
#  7     2021-08        123.655380    ABT
#  8     2021-09        125.434586    ABT
#  9     2021-10        120.686462    ABT
#  10    2021-11        128.051696    ABT,
#     year-month  mean_price_month Symbol
#  0     2021-01        106.306940   ABBV
#  1     2021-02        104.102500   ABBV
#  2     2021-03        104.588965   ABBV
#  3     2021-04        107.164648   ABBV
#  4     2021-05        114.180284   ABBV
#  5     2021-06        112.473855   ABBV
#  6     2021-07        115.887569   ABBV
#  7     2021-08        116.727660   ABBV
#  8     2021-09        107.857295   ABBV
#  9     2021-10        108.961461   ABBV
#  10    2021-11        116.604105   ABBV]

# %%
all_data = pd.concat(new_data, axis= 0)
all_data
# Out:
#    year-month  mean_price_month Symbol
# 0     2021-01        168.634545    MMM
# 1     2021-02        175.314258    MMM
# 2     2021-03        184.209234    MMM
# 3     2021-04        194.874722    MMM
# 4     2021-05        200.248844    MMM
# ..        ...               ...    ...
# 6     2021-07        155.304703    AIZ
# 7     2021-08        163.733684    AIZ
# 8     2021-09        164.608095    AIZ
# 9     2021-10        162.282851    AIZ
# 10    2021-11        161.438641    AIZ
#
# [561 rows x 3 columns]

# %%
all_data.reset_index(inplace=True)

# %%
all_data
# Out:
#      index year-month  mean_price_month Symbol
# 0        0    2021-01        168.634545    MMM
# 1        1    2021-02        175.314258    MMM
# 2        2    2021-03        184.209234    MMM
# 3        3    2021-04        194.874722    MMM
# 4        4    2021-05        200.248844    MMM
# ..     ...        ...               ...    ...
# 556      6    2021-07        155.304703    AIZ
# 557      7    2021-08        163.733684    AIZ
# 558      8    2021-09        164.608095    AIZ
# 559      9    2021-10        162.282851    AIZ
# 560     10    2021-11        161.438641    AIZ
#
# [561 rows x 4 columns]

# %%
all_data.dtypes
# Out:
# index                   int64
# year-month          period[M]
# mean_price_month      float64
# Symbol                 object
# dtype: object

# %%
all_data['year-month'] = all_data['year-month'].astype(str)

# %%
all_data.dtypes
# Out:
# index                 int64
# year-month           object
# mean_price_month    float64
# Symbol               object
# dtype: object

# %%
all_data['month'] = pd.DatetimeIndex(all_data['year-month']).month

# %%
all_data
# Out:
#      index year-month  mean_price_month Symbol  month
# 0        0    2021-01        168.634545    MMM      1
# 1        1    2021-02        175.314258    MMM      2
# 2        2    2021-03        184.209234    MMM      3
# 3        3    2021-04        194.874722    MMM      4
# 4        4    2021-05        200.248844    MMM      5
# ..     ...        ...               ...    ...    ...
# 556      6    2021-07        155.304703    AIZ      7
# 557      7    2021-08        163.733684    AIZ      8
# 558      8    2021-09        164.608095    AIZ      9
# 559      9    2021-10        162.282851    AIZ     10
# 560     10    2021-11        161.438641    AIZ     11
#
# [561 rows x 5 columns]

# %%
all_data.dtypes
# Out:
# index                 int64
# year-month           object
# mean_price_month    float64
# Symbol               object
# month                 int64
# dtype: object

# %%
import calendar
all_data['month'] = all_data['month'].apply(lambda x: calendar.month_abbr[x])

# %%
all_data
# Out:
#      index year-month  mean_price_month Symbol month
# 0        0    2021-01        168.634545    MMM   Jan
# 1        1    2021-02        175.314258    MMM   Feb
# 2        2    2021-03        184.209234    MMM   Mar
# 3        3    2021-04        194.874722    MMM   Apr
# 4        4    2021-05        200.248844    MMM   May
# ..     ...        ...               ...    ...   ...
# 556      6    2021-07        155.304703    AIZ   Jul
# 557      7    2021-08        163.733684    AIZ   Aug
# 558      8    2021-09        164.608095    AIZ   Sep
# 559      9    2021-10        162.282851    AIZ   Oct
# 560     10    2021-11        161.438641    AIZ   Nov
#
# [561 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

plt.figure(figsize = (20,15))

sns.lineplot(data=all_data, x='month', y='mean_price_month', hue='Symbol', sort=False)

# %% [markdown]
# #### 7-day rolling average

# %%
data2=[]

for symbol in ticker_symbols[:51]:
    url = "https://api.tiingo.com/tiingo/daily/{}/prices?startDate=2021-01-01&endDate={}&format=csv&token={}".format(symbol,end_date,token1)
    r = requests.get(url,timeout=10)
    #print(r)
    rows=r.text.split("\n")[1:-1]
    #print(rows)
    df=pd.DataFrame(rows)
    #print("raw df:",df.head())
    df=df.iloc[:,0].str.split(",",13,expand=True)
    #print("clean df", df.head())
    df["Symbol"]=symbol
    #print("symbol df", df.head())
    data2.append(df)
data2[:1]
# Out:
# [              0       1       2         3       4        5                 6  \
#  0    2021-01-04  171.87   176.2  170.5504   175.0  2996278  166.545800945774
#  1    2021-01-05  171.58  173.25    170.65  172.01  2295297  166.264784582975
#  2    2021-01-06  174.19  175.57    172.04  172.72  3346410  168.793931848166
#  3    2021-01-07  169.72  173.46    166.16  171.56  5863373  164.462403773298
#  4    2021-01-08  166.62  169.54    164.61  169.17  4808130   161.45843575717
#  ..          ...     ...     ...       ...     ...      ...               ...
#  218  2021-11-12  183.66   186.3   180.285  180.95  4395646   182.15200110957
#  219  2021-11-15  183.31  185.04     182.9  184.09  1463522  181.804874895978
#  220  2021-11-16  183.37   184.2     182.7  183.31  1974979  181.864382246879
#  221  2021-11-17  183.34  183.87    181.63  183.37  2251139  181.834628571429
#  222  2021-11-18  178.77  182.54    178.69  182.11  2522091            178.77
#
#                      7                 8                 9       10    11   12  \
#  0    170.741665948946  165.267079592844  169.578839620122  2996278   0.0  1.0
#  1    167.883051223921  165.363594178136   166.68146401747  2295297   0.0  1.0
#  2    170.131182126313   166.71053467569  167.369469595357  3346410   0.0  1.0
#  3    168.086545831465  161.012685664454  166.245404144161  5863373   0.0  1.0
#  4    164.287979823974   159.51070165639   163.92944170592  4808130   0.0  1.0
#  ..                ...               ...               ...      ...   ...  ...
#  218  184.770324549237  178.804712621359  179.464252427184  4395646   0.0  1.0
#  219  183.520670180305  181.398241331484  182.578470457698  1463522   0.0  1.0
#  220  182.687567267684  181.199883495146  181.804874895978  1974979   0.0  1.0
#  221  182.360276837725  180.138669070735  181.864382246879  2251139   0.0  1.0
#  222            182.54            178.69            182.11  2522091  1.48  1.0
#
#      Symbol
#  0      MMM
#  1      MMM
#  2      MMM
#  3      MMM
#  4      MMM
#  ..     ...
#  218    MMM
#  219    MMM
#  220    MMM
#  221    MMM
#  222    MMM
#
#  [223 rows x 14 columns]]

# %%
new_data2 = []
for index in range(len(data2)):
    print(index)
    sub_data=data2[index]
    sub_data.drop(sub_data.columns[[5,10,11,12]], axis=1, inplace=True) 
    sub_data[[1,2,3,4,6,7,8,9]] = sub_data[[1,2,3,4,6,7,8,9]].apply(pd.to_numeric)
    sub_data[0]= pd.to_datetime(sub_data[0])
    sub_data['mean_price_everyday'] = sub_data.iloc[:, 1:9].mean(axis=1)
    sub_data['7day_ave'] = sub_data['mean_price_everyday'].rolling(7).mean()
    sub_data.rename(columns={0: 'ymd'}, inplace=True)
    sub_data = sub_data[['ymd', '7day_ave', 'Symbol']]
    print(sub_data.head())
    new_data2.append(sub_data)
new_data2[:1]
# Out:
# 0
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    MMM
# 1 2021-01-05       NaN    MMM
# 2 2021-01-06       NaN    MMM
# 3 2021-01-07       NaN    MMM
# 4 2021-01-08       NaN    MMM
# 1
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ABT
# 1 2021-01-05       NaN    ABT
# 2 2021-01-06       NaN    ABT
# 3 2021-01-07       NaN    ABT
# 4 2021-01-08       NaN    ABT
# 2
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ABBV
# 1 2021-01-05       NaN   ABBV
# 2 2021-01-06       NaN   ABBV
# 3 2021-01-07       NaN   ABBV
# 4 2021-01-08       NaN   ABBV
# 3
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ABMD
# 1 2021-01-05       NaN   ABMD
# 2 2021-01-06       NaN   ABMD
# 3 2021-01-07       NaN   ABMD
# 4 2021-01-08       NaN   ABMD
# 4
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ACN
# 1 2021-01-05       NaN    ACN
# 2 2021-01-06       NaN    ACN
# 3 2021-01-07       NaN    ACN
# 4 2021-01-08       NaN    ACN
# 5
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ATVI
# 1 2021-01-05       NaN   ATVI
# 2 2021-01-06       NaN   ATVI
# 3 2021-01-07       NaN   ATVI
# 4 2021-01-08       NaN   ATVI
# 6
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ADBE
# 1 2021-01-05       NaN   ADBE
# 2 2021-01-06       NaN   ADBE
# 3 2021-01-07       NaN   ADBE
# 4 2021-01-08       NaN   ADBE
# 7
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AMD
# 1 2021-01-05       NaN    AMD
# 2 2021-01-06       NaN    AMD
# 3 2021-01-07       NaN    AMD
# 4 2021-01-08       NaN    AMD
# 8
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AAP
# 1 2021-01-05       NaN    AAP
# 2 2021-01-06       NaN    AAP
# 3 2021-01-07       NaN    AAP
# 4 2021-01-08       NaN    AAP
# 9
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AES
# 1 2021-01-05       NaN    AES
# 2 2021-01-06       NaN    AES
# 3 2021-01-07       NaN    AES
# 4 2021-01-08       NaN    AES
# 10
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AFL
# 1 2021-01-05       NaN    AFL
# 2 2021-01-06       NaN    AFL
# 3 2021-01-07       NaN    AFL
# 4 2021-01-08       NaN    AFL
# 11
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN      A
# 1 2021-01-05       NaN      A
# 2 2021-01-06       NaN      A
# 3 2021-01-07       NaN      A
# 4 2021-01-08       NaN      A
# 12
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    APD
# 1 2021-01-05       NaN    APD
# 2 2021-01-06       NaN    APD
# 3 2021-01-07       NaN    APD
# 4 2021-01-08       NaN    APD
# 13
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   AKAM
# 1 2021-01-05       NaN   AKAM
# 2 2021-01-06       NaN   AKAM
# 3 2021-01-07       NaN   AKAM
# 4 2021-01-08       NaN   AKAM
# 14
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ALK
# 1 2021-01-05       NaN    ALK
# 2 2021-01-06       NaN    ALK
# 3 2021-01-07       NaN    ALK
# 4 2021-01-08       NaN    ALK
# 15
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ALB
# 1 2021-01-05       NaN    ALB
# 2 2021-01-06       NaN    ALB
# 3 2021-01-07       NaN    ALB
# 4 2021-01-08       NaN    ALB
# 16
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ARE
# 1 2021-01-05       NaN    ARE
# 2 2021-01-06       NaN    ARE
# 3 2021-01-07       NaN    ARE
# 4 2021-01-08       NaN    ARE
# 17
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ALGN
# 1 2021-01-05       NaN   ALGN
# 2 2021-01-06       NaN   ALGN
# 3 2021-01-07       NaN   ALGN
# 4 2021-01-08       NaN   ALGN
# 18
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ALLE
# 1 2021-01-05       NaN   ALLE
# 2 2021-01-06       NaN   ALLE
# 3 2021-01-07       NaN   ALLE
# 4 2021-01-08       NaN   ALLE
# 19
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    LNT
# 1 2021-01-05       NaN    LNT
# 2 2021-01-06       NaN    LNT
# 3 2021-01-07       NaN    LNT
# 4 2021-01-08       NaN    LNT
# 20
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ALL
# 1 2021-01-05       NaN    ALL
# 2 2021-01-06       NaN    ALL
# 3 2021-01-07       NaN    ALL
# 4 2021-01-08       NaN    ALL
# 21
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN  GOOGL
# 1 2021-01-05       NaN  GOOGL
# 2 2021-01-06       NaN  GOOGL
# 3 2021-01-07       NaN  GOOGL
# 4 2021-01-08       NaN  GOOGL
# 22
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   GOOG
# 1 2021-01-05       NaN   GOOG
# 2 2021-01-06       NaN   GOOG
# 3 2021-01-07       NaN   GOOG
# 4 2021-01-08       NaN   GOOG
# 23
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN     MO
# 1 2021-01-05       NaN     MO
# 2 2021-01-06       NaN     MO
# 3 2021-01-07       NaN     MO
# 4 2021-01-08       NaN     MO
# 24
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   AMZN
# 1 2021-01-05       NaN   AMZN
# 2 2021-01-06       NaN   AMZN
# 3 2021-01-07       NaN   AMZN
# 4 2021-01-08       NaN   AMZN
# 25
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   AMCR
# 1 2021-01-05       NaN   AMCR
# 2 2021-01-06       NaN   AMCR
# 3 2021-01-07       NaN   AMCR
# 4 2021-01-08       NaN   AMCR
# 26
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AEE
# 1 2021-01-05       NaN    AEE
# 2 2021-01-06       NaN    AEE
# 3 2021-01-07       NaN    AEE
# 4 2021-01-08       NaN    AEE
# 27
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AAL
# 1 2021-01-05       NaN    AAL
# 2 2021-01-06       NaN    AAL
# 3 2021-01-07       NaN    AAL
# 4 2021-01-08       NaN    AAL
# 28
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AEP
# 1 2021-01-05       NaN    AEP
# 2 2021-01-06       NaN    AEP
# 3 2021-01-07       NaN    AEP
# 4 2021-01-08       NaN    AEP
# 29
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AXP
# 1 2021-01-05       NaN    AXP
# 2 2021-01-06       NaN    AXP
# 3 2021-01-07       NaN    AXP
# 4 2021-01-08       NaN    AXP
# 30
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AIG
# 1 2021-01-05       NaN    AIG
# 2 2021-01-06       NaN    AIG
# 3 2021-01-07       NaN    AIG
# 4 2021-01-08       NaN    AIG
# 31
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AMT
# 1 2021-01-05       NaN    AMT
# 2 2021-01-06       NaN    AMT
# 3 2021-01-07       NaN    AMT
# 4 2021-01-08       NaN    AMT
# 32
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AWK
# 1 2021-01-05       NaN    AWK
# 2 2021-01-06       NaN    AWK
# 3 2021-01-07       NaN    AWK
# 4 2021-01-08       NaN    AWK
# 33
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AMP
# 1 2021-01-05       NaN    AMP
# 2 2021-01-06       NaN    AMP
# 3 2021-01-07       NaN    AMP
# 4 2021-01-08       NaN    AMP
# 34
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ABC
# 1 2021-01-05       NaN    ABC
# 2 2021-01-06       NaN    ABC
# 3 2021-01-07       NaN    ABC
# 4 2021-01-08       NaN    ABC
# 35
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AME
# 1 2021-01-05       NaN    AME
# 2 2021-01-06       NaN    AME
# 3 2021-01-07       NaN    AME
# 4 2021-01-08       NaN    AME
# 36
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   AMGN
# 1 2021-01-05       NaN   AMGN
# 2 2021-01-06       NaN   AMGN
# 3 2021-01-07       NaN   AMGN
# 4 2021-01-08       NaN   AMGN
# 37
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    APH
# 1 2021-01-05       NaN    APH
# 2 2021-01-06       NaN    APH
# 3 2021-01-07       NaN    APH
# 4 2021-01-08       NaN    APH
# 38
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ADI
# 1 2021-01-05       NaN    ADI
# 2 2021-01-06       NaN    ADI
# 3 2021-01-07       NaN    ADI
# 4 2021-01-08       NaN    ADI
# 39
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ANSS
# 1 2021-01-05       NaN   ANSS
# 2 2021-01-06       NaN   ANSS
# 3 2021-01-07       NaN   ANSS
# 4 2021-01-08       NaN   ANSS
# 40
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ANTM
# 1 2021-01-05       NaN   ANTM
# 2 2021-01-06       NaN   ANTM
# 3 2021-01-07       NaN   ANTM
# 4 2021-01-08       NaN   ANTM
# 41
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AON
# 1 2021-01-05       NaN    AON
# 2 2021-01-06       NaN    AON
# 3 2021-01-07       NaN    AON
# 4 2021-01-08       NaN    AON
# 42
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AOS
# 1 2021-01-05       NaN    AOS
# 2 2021-01-06       NaN    AOS
# 3 2021-01-07       NaN    AOS
# 4 2021-01-08       NaN    AOS
# 43
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    APA
# 1 2021-01-05       NaN    APA
# 2 2021-01-06       NaN    APA
# 3 2021-01-07       NaN    APA
# 4 2021-01-08       NaN    APA
# 44
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   AAPL
# 1 2021-01-05       NaN   AAPL
# 2 2021-01-06       NaN   AAPL
# 3 2021-01-07       NaN   AAPL
# 4 2021-01-08       NaN   AAPL
# 45
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   AMAT
# 1 2021-01-05       NaN   AMAT
# 2 2021-01-06       NaN   AMAT
# 3 2021-01-07       NaN   AMAT
# 4 2021-01-08       NaN   AMAT
# 46
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   APTV
# 1 2021-01-05       NaN   APTV
# 2 2021-01-06       NaN   APTV
# 3 2021-01-07       NaN   APTV
# 4 2021-01-08       NaN   APTV
# 47
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    ADM
# 1 2021-01-05       NaN    ADM
# 2 2021-01-06       NaN    ADM
# 3 2021-01-07       NaN    ADM
# 4 2021-01-08       NaN    ADM
# 48
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN   ANET
# 1 2021-01-05       NaN   ANET
# 2 2021-01-06       NaN   ANET
# 3 2021-01-07       NaN   ANET
# 4 2021-01-08       NaN   ANET
# 49
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AJG
# 1 2021-01-05       NaN    AJG
# 2 2021-01-06       NaN    AJG
# 3 2021-01-07       NaN    AJG
# 4 2021-01-08       NaN    AJG
# 50
#          ymd  7day_ave Symbol
# 0 2021-01-04       NaN    AIZ
# 1 2021-01-05       NaN    AIZ
# 2 2021-01-06       NaN    AIZ
# 3 2021-01-07       NaN    AIZ
# 4 2021-01-08       NaN    AIZ
# [           ymd    7day_ave Symbol
#  0   2021-01-04         NaN    MMM
#  1   2021-01-05         NaN    MMM
#  2   2021-01-06         NaN    MMM
#  3   2021-01-07         NaN    MMM
#  4   2021-01-08         NaN    MMM
#  ..         ...         ...    ...
#  218 2021-11-12  181.115702    MMM
#  219 2021-11-15  181.437945    MMM
#  220 2021-11-16  181.611871    MMM
#  221 2021-11-17  181.765168    MMM
#  222 2021-11-18  181.742646    MMM
#
#  [223 rows x 3 columns]]

# %%
all_data2 = pd.concat(new_data2, axis= 0)
all_data2
# Out:
#            ymd    7day_ave Symbol
# 0   2021-01-04         NaN    MMM
# 1   2021-01-05         NaN    MMM
# 2   2021-01-06         NaN    MMM
# 3   2021-01-07         NaN    MMM
# 4   2021-01-08         NaN    MMM
# ..         ...         ...    ...
# 218 2021-11-12  161.496782    AIZ
# 219 2021-11-15  160.966429    AIZ
# 220 2021-11-16  160.495714    AIZ
# 221 2021-11-17  160.239786    AIZ
# 222 2021-11-18  160.303714    AIZ
#
# [11373 rows x 3 columns]

# %% [markdown]
# all_data2 = all_data2.sort_values(by='7day_ave', ascending=False)
# all_data2

# %%
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

plt.figure(figsize = (20,15))

sns.lineplot(data=all_data2, x='ymd', y='7day_ave', hue='Symbol', sort=False)

# %% [markdown]
# ### 5. Save dataset into csv file

# %%
df_final=pd.concat(data1)
df_final.drop(df_final.iloc[:,6:13],axis=1,inplace=True)
df_final.to_csv(r"/Users/anniephan/Desktop/Data_Science_Master/DATA_1050/Fall_2021/Homework_11/historicalSP_quotes.csv",index=False)

# %%
df_final.head()
# Out:
#             0       1       2       3       4        5 Symbol
# 0  2019-01-03  183.76  188.28  182.89  188.28  3358241    MMM
# 1  2019-01-04  191.32  191.98  186.03  186.75  2995052    MMM
# 2  2019-01-07  190.88   192.3  188.66  191.36  2162158    MMM
# 3  2019-01-08  191.68  194.11  189.58   193.0  2479787    MMM
# 4  2019-01-09   192.3  193.94  191.38  193.25  2163815    MMM

# %%
df_final
# Out:
#               0       1       2        3       4        5 Symbol
# 0    2019-01-03  183.76  188.28   182.89  188.28  3358241    MMM
# 1    2019-01-04  191.32  191.98   186.03  186.75  2995052    MMM
# 2    2019-01-07  190.88   192.3   188.66  191.36  2162158    MMM
# 3    2019-01-08  191.68  194.11   189.58   193.0  2479787    MMM
# 4    2019-01-09   192.3  193.94   191.38  193.25  2163815    MMM
# ..          ...     ...     ...      ...     ...      ...    ...
# 722  2021-11-12  160.22   160.8   158.35  160.42   325459    AIZ
# 723  2021-11-15  160.11  161.48   159.57  160.96   394338    AIZ
# 724  2021-11-16  160.56  161.84   159.99  160.26   303662    AIZ
# 725  2021-11-17  161.03  161.52  158.924  160.56   232632    AIZ
# 726  2021-11-18  160.24  161.79   159.48  161.23   350963    AIZ
#
# [36968 rows x 7 columns]

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ## Step 3: Automating and Scheduling Python scripts on Google Cloud Compute Engine

# %% [markdown]
# ## Step 4: Storing output tables into GoogleCloudStorage

# %%
import os
from google.cloud.storage.blob import Blob
os.environ['GOOGLE_APPLICATION_CREDENTIALS']=r"/home/annie_ptba/My First Project-506764075115.json"
storage_client = storage.Client()
bucket = storage_client.get_bucket("draft_gcp_1")
data=bucket.blob("SP500stocks.csv")
data.upload_from_filename(r"/home/annie_ptba/SP500stocks.csv")

# %% [markdown]
# ## Step 5: Use CloudFunctions to automate file transfer from CloudStorage into GoogleBigQuery

# %%
def csvloader(data,context):
    from google.cloud import bigquery
    client = bigquery.Client()
    table_ref = client.dataset("csm").table("SPhistorical")
    job_config = bigquery.LoadJobConfig()
    job_config.write_disposition =     bigquery.WriteDisposition.WRITE_TRUNCATE
    job_config.skip_leading_rows = 1
    
    job_config.source_format = bigquery.SourceFormat.CSV
    uri = "gs://csm_erat/Data/historicalSP_quotes.csv"
    load_job = client.load_table_from_uri(uri, table_ref, job_config=job_config)
load_job.result()
    destination_table = client.get_table(table_ref)
